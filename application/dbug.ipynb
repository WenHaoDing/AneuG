# %%
import sys
sys.path.append("..")
import os
import open3d as o3d
from pytorch3d.structures import Meshes
from pytorch3d.io import load_objs_as_meshes, save_obj
from utils.utils import safe_load_mesh

# %%
mesh_path = "../datasets/australian/005/005.obj"
mesh = o3d.io.read_triangle_mesh(mesh_path)
save_path = os.path.join(os.path.dirname(mesh_path), "005.vtp")
o3d.io.write_triangle_mesh(save_path, mesh)
# Out:
# [Open3D WARNING] Write geometry::TriangleMesh failed: unknown file extension.
# False
