# %%
import torch
import os
import torch.nn as nn
from torch.utils.data import DataLoader
from utils.utils import safe_load_mesh
import pickle
import sys
from models.vae_models import VAE, VAE2, KL_divergence
from models.discriminators import PointNet2, GHD_Reconstruct
from models.losses import wgan_gradient_penalty
from torch_geometric.data import Data
import torch.nn.functional as F
import wandb
import matplotlib.pyplot as plt
from models.utils import save_models, load_models, plot_wandb
from sklearn.decomposition import PCA
import numpy as np
import pytorch3d
from pytorch3d.loss import mesh_laplacian_smoothing, mesh_normal_consistency
from losses.mesh_loss import Rigid_Loss
from models.vae_datasets import GHDDataset as Dataset
from models.utils import get_fig, get_fig_advanced
from IPython.display import Image

# %%
# data conf
root = '/media/yaplab/"HDD Storage"/wenhao/ghb_aneurysms'
ghd_chk_root = os.path.join(root, 'checkpoints/fit_mca_stable')
ghd_run = 'vanilla'
ghd_chk_name = 'ghb_fitting_checkpoint_5.pkl'
eigen_chk = os.path.join(root, "checkpoints/canonical_typeB_144.pkl")
alignment_root = os.path.join(root, 'checkpoints/align_mca_female')
canonical_name = 'canonical_typeB'
canonical_Meshes = safe_load_mesh(os.path.join(alignment_root, canonical_name, 'part_aligned_updated.obj'))
cases = [case for case in os.listdir(ghd_chk_root) if os.path.isdir(os.path.join(ghd_chk_root, case)) and case != canonical_name]
# model conf
epochs = 1001
hidden_dim = 108
latent_dim = 108
batch_size = 128
mode = 'train'
device = torch.device('cuda:0')
use_norm = True
use_reg = True
rigidloss = Rigid_Loss(canonical_Meshes.to(device))
use_discriminator = True
pure_gan = False
reload_epoch = 10000
# meta
meta = 'stable_108_h108_fixreg'
withscale = False
log_path = os.path.join("./checkpoints/paper/VAE", meta)
get_gif = False
save_objs = False

# %%
from models.mesh_plugins import MeshPlugins, MeshRegulizer
import pyvista as pv
pv.set_jupyter_backend('html')
pv.start_xvfb()

cep_chk = "./data/excision_registration/combined_stable/canonical_typeB/diff_centreline_checkpoint.pkl"
trimmed_mesh_path = os.path.join(os.getcwd(), "data/excision_registration/combined_stable/canonical_typeB/part_trimmed_short.obj")
wave_based_trimming = False
mesh_plugin = MeshPlugins(canonical_Meshes, cep_chk, 
                          max_loops=[15, 13, 12], loop_start=[11, 9, 8], 
                          trimmed_mesh_path=trimmed_mesh_path, wave_based_trimming=wave_based_trimming)
print(mesh_plugin.cap_faces)
print("visualize mesh regulizer for calibration")
mesh_regulizer = MeshRegulizer(mesh_plugin, device=device, visualize=False)
# trumpet_loss = mesh_regulizer.trumpet_loss(canonical_Meshes)

# %%
# dataset
ghd_reconstruct = GHD_Reconstruct(canonical_Meshes, eigen_chk, num_Basis=12**2, device=device)
dataset = Dataset(ghd_chk_root, ghd_run, ghd_chk_name, ghd_reconstruct, cases, withscale=withscale, normalize=True)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=4)
mean, std = dataset.get_mean_std()
# model
generator = VAE(dataset.get_dim(), hidden_dim, latent_dim, withscale=withscale).to(device)
discriminator = PointNet2(use_norm=use_norm).to(device)
optimizer_G = torch.optim.Adam(generator.parameters(), lr=0.001, betas=(0.9, 0.999))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_G = torch.optim.lr_scheduler.StepLR(optimizer_G, step_size=2000, gamma=0.5)
scheduler_D = torch.optim.lr_scheduler.StepLR(optimizer_D, step_size=2000, gamma=0.5)
# reload
generator, discriminator, optimizer_G, optimizer_D, epoch_ = load_models(generator, discriminator, optimizer_G, optimizer_D, log_path, reload_epoch, generator_only=True)
generator.eval()

# %%
"""mesh render"""
from render.mesh_renders import MeshRender

out_dir = "./render/gifs"
mesh_render = MeshRender(out_dir=out_dir, device=device)
mesh_render.init_mesh_render(image_size=1024, dist=1, elev=45, azim=90)

# %%
# %matplotlib widget
# unconditional generation
label='unconditional_generation'
B = 32
z = torch.randn(B, latent_dim).to(device) * 1.0
if withscale:
    ghd_fake, scale_fake = generator.decode(z, False)
    scale_fake = dataset.denorm_scale(scale_fake)
else:
    ghd_fake = generator.decode(z, True)
    scale_fake = None
data_fake = ghd_reconstruct.forward(ghd_fake, mean, std, use_norm)
# fig = get_fig(ghd_reconstruct, data_fake, 4, Title="Unconditional Generation")
# plt.show(fig)
fig2 = get_fig_advanced(ghd_reconstruct, data_fake, 8, Title=None, mesh_plugin=mesh_plugin, plot_tangent=False, scale=scale_fake)
save_path = "render/images/unconditional/{}/{}.png".format(label, meta)
os.makedirs(os.path.dirname(save_path), exist_ok=True)
plt.savefig(save_path)
plt.show(fig2)

# create gifs
meshes = ghd_reconstruct.ghd_forward_as_Meshes(ghd_fake * std.to(device) + mean.to(device), denormalize_shape=False, trimmed_faces=mesh_plugin.trimmed_faces)

if get_gif:
    # meshes = ghd_reconstruct.ghd_forward_as_Meshes(ghd_fake * std.to(device) + mean.to(device), denormalize_shape=False, trimmed_faces=None)
    out_dir = "render/wepage/unconditional"
    mesh_render.render_rotational_gif(meshes, dual_texture=False, n_row=8, fps=36, out_dir=out_dir, label=label)
try:
    # display(Image(filename=f"./render/gifs/{label}.gif"))
    pass
except:
    pass
if save_objs:
    save_dir = "render/meshes/unconditional/{}/{}".format(label, meta)
    os.makedirs(os.path.dirname(save_dir), exist_ok=True)
    mesh_render.save_objs(meshes, label, save_dir=save_dir, add_random_string=False)
# ur = input("Please input UR: ")
# dl = input("Please input DL, ranging from 1-3: ")
# ur = "none"
# dl = "none"

# %%
# Evaluator
from evaluators import GenerationEvaluator, save_metrics_to_excel

evaluator = GenerationEvaluator(dataset, ghd_reconstruct, mesh_plugin, dmm_calculator=None, root=os.getcwd())
B = 512
z = torch.randn(B, latent_dim).to(device)
ghd_fake = generator.decode(z, True)
ghd_real = next(iter(dataloader)).to(device)
if withscale:
    ghd_real, scale_real = ghd_real[:, :-1], ghd_real[:, -1:]
else:
    scale_real = None
ghd_recon, _, _ = generator(ghd_real, scale_real)

input_real, input_fake = evaluator.preprocess_ghd(ghd_real, ghd_fake)
fpd = evaluator.compute_fpd(input_real, input_fake)
kpd = evaluator.compute_kpd(input_real, input_fake)
tmd = evaluator.compute_tmd(input_fake)
tmd_real = evaluator.compute_tmd(input_real)
cd_v, cd_n = evaluator.compute_cd(ghd_real, ghd_recon, mean, std)
print(f"FPD: {fpd}, KPD: {kpd}, TMD: {tmd}, CD_V: {cd_v}, CD_N: {cd_n}, TMD_real: {tmd_real}")

# save csv
file_path = "metrics.xlsx"
sheet_name = "unconditional_GHD_VAE"
run_type = "unconditional"
metrics = {"latent_dim": latent_dim, "hidden_dim": hidden_dim, "withscale": withscale, "FPD": fpd, "KPD (10^3)": 1e3*kpd, "TMD (10^4)": 1e4*tmd, "ur": ur, "dl": dl,
           "CD_V (10^4)": 1e4*cd_v, "CD_N (10^2)": 1e2*cd_n}
# save_metrics_to_excel(file_path, sheet_name, meta, run_type, metrics)

# %%
# Evaluator PCA
from evaluators import GenerationEvaluator, save_metrics_to_excel

evaluator = GenerationEvaluator(dataset, ghd_reconstruct, mesh_plugin, dmm_calculator=None, root=os.getcwd())
B = 512
z = torch.randn(B, latent_dim).to(device)
ghd_fake = generator.decode(z, True)
ghd_real = next(iter(dataloader)).to(device)
if withscale:
    ghd_real, scale_real = ghd_real[:, :-1], ghd_real[:, -1:]
else:
    scale_real = None
ghd_recon, _, _ = generator(ghd_real, scale_real)

input_real, input_fake = evaluator.preprocess_ghd(ghd_real, ghd_fake)
input_fake = torch.load("./render/meshes/pca/pca_generation.pth")
input_fake = torch.Tensor(input_fake).to(device)
fpd = evaluator.compute_fpd(input_real, input_fake)
kpd = evaluator.compute_kpd(input_real, input_fake)
tmd = evaluator.compute_tmd(input_fake)
cd_v, cd_n = evaluator.compute_cd(ghd_real, ghd_recon, mean, std)
print(f"FPD: {fpd}, KPD: {kpd}, TMD: {tmd}, CD_V: {cd_v}, CD_N: {cd_n}")

# save csv
file_path = "metrics.xlsx"
sheet_name = "unconditional_GHD_VAE"
run_type = "unconditional"
metrics = {"latent_dim": latent_dim, "hidden_dim": hidden_dim, "withscale": withscale, "FPD": fpd, "KPD (10^3)": 1e3*kpd, "TMD (10^4)": 1e4*tmd, "ur": ur, "dl": dl,
           "CD_V (10^4)": 1e4*cd_v, "CD_N (10^2)": 1e2*cd_n}
# save_metrics_to_excel(file_path, sheet_name, "PCA", run_type, metrics)

# %%
"""plot Umap"""
import umap
from sklearn.cluster import KMeans

style = 'fake'

# extract latent
B = 1024
z = torch.randn(B, latent_dim).to(device)
if withscale:
    ghd_fake, scale_fake = generator.decode(z, False)
else:
    ghd_fake = generator.decode(z, True)
    scale_fake = None
mu, logvar = generator.encode(ghd_fake, scale_fake)
z_fake = mu
mu, logvar = generator.encode(ghd_real, scale_real)
z_real = mu

if style == 'fake':
    fit = umap.UMAP(n_neighbors=20)
    u = fit.fit_transform(z_fake.detach().cpu().numpy())
else:
    fit = umap.UMAP(n_neighbors=2)
    u = fit.fit_transform(z_real.detach().cpu().numpy())

# cluster
kmeans = KMeans(n_clusters=8, random_state=55).fit(u)
labels_fake = kmeans.labels_
u_centers = kmeans.cluster_centers_

# plot UMAP with different colors for each cluster
# Define markers
markers = ['o', '^', '*', '+', 'h']
unique_labels = np.unique(labels_fake)
colors = plt.cm.viridis(np.linspace(0, 1, len(unique_labels)))

# Plot UMAP with fixed markers and unique colors
for i, label in enumerate(unique_labels):
    mask = (labels_fake == label)  # Select points for the current cluster
    plt.scatter(
        u[mask, 0], u[mask, 1],
        alpha=0.3,
        marker=markers[i % len(markers)],  # Assign marker
        color=colors[i]  # Assign color
    )
    plt.scatter(u_centers[i, 0], u_centers[i, 1], c=colors[i], marker="2", s=100)
    # plt.text(u_centers[i, 0], u_centers[i, 1], str(i), fontsize=12, ha='right')
save_path = "render/images/unconditional/{}/{}.png".format("umap", meta)
os.makedirs(os.path.dirname(save_path), exist_ok=True)
plt.savefig(save_path)
plt.show()

# Reverse transform u_centers to get the corresponding z values
z_cluster = torch.Tensor(fit.inverse_transform(u_centers)).to(device)
if withscale:
    ghd_cluster, scale_cluster = generator.decode(z_cluster, False)
    scale_cluster = dataset.denorm_scale(scale_cluster)
else:
    ghd_cluster = generator.decode(z_cluster)
    scale_cluster = None
data_cluster = ghd_reconstruct.forward(ghd_cluster, mean, std, use_norm)
fig_cluster = get_fig_advanced(ghd_reconstruct, data_cluster, 4, Title="Clusters", mesh_plugin=mesh_plugin, plot_tangent=True, scale=scale_cluster)
save_path = "render/images/unconditional/{}/{}.png".format("umap_clusters", meta)
os.makedirs(os.path.dirname(save_path), exist_ok=True)
plt.savefig(save_path)
plt.show(fig_cluster)
if save_objs:
    label = "umap_clusters"
    meshes = ghd_reconstruct.ghd_forward_as_Meshes(ghd_cluster, trimmed_faces=mesh_plugin.trimmed_faces, mean=mean, std=std)
    save_dir = "render/meshes/unconditional/{}/{}".format(label, meta)
    os.makedirs(os.path.dirname(save_dir), exist_ok=True)
    mesh_render.save_objs(meshes, label, save_dir=save_dir)

# %%
# near-neighbour generation
label='near_neighbour'
shape_id = 2
B = 12
ghd_real = next(iter(dataloader)).to(device)
if withscale:
    ghd_real, scale_real = ghd_real[:, :-1], ghd_real[:, -1:]
else:
    scale_real = None
mu, logvar = generator.encode(ghd_real, scale_real)
mu = mu[shape_id].unsqueeze(0).repeat(B, 1)
logvar = logvar[shape_id].unsqueeze(0).repeat(B, 1)
latent_std = torch.exp(logvar/2)
# z = mu + torch.randn_like(latent_std) * latent_std
if latent_dim > 64:
    z = mu + torch.randn_like(latent_std) * 0.5
else:
    z = mu + torch.randn_like(latent_std) * 0.5

if withscale:
    ghd_fake, scale_fake = generator.decode(z, False)
else:
    ghd_fake = generator.decode(z, True)
    scale_fake = None
data_fake = ghd_reconstruct.forward(ghd_fake, mean, std, use_norm)
fig = get_fig(ghd_reconstruct, data_fake, 5, Title="Near-Neighbour Generation")
save_path = "render/images/unconditional/{}/{}.png".format(label, meta)
os.makedirs(os.path.dirname(save_path), exist_ok=True)
plt.savefig(save_path)
plt.show(fig)

# create gifs
meshes = ghd_reconstruct.ghd_forward_as_Meshes(ghd_fake * std.to(device) + mean.to(device), denormalize_shape=False, trimmed_faces=mesh_plugin.trimmed_faces)
if get_gif:
    mesh_render.render_rotational_gif(meshes, dual_texture=False, n_row=5, fps=36, out_dir=None, label=label)
    display(Image(filename=f"./render/gifs/{label}.gif"))
try:
    display(Image(filename=f"./render/gifs/{label}.gif"))
except:
    pass
if save_objs:
    save_dir = "render/meshes/unconditional/{}/{}".format(label, meta)
    os.makedirs(os.path.dirname(save_dir), exist_ok=True)
    mesh_render.save_objs(meshes, label, save_dir=save_dir)

# %%
# interpolation
label='interpolation'
B = 10
shape_id_l = 7
shape_id_r = 2
ghd_real = next(iter(dataloader)).to(device)
if withscale:
    ghd_real, scale_real = ghd_real[:, :-1], ghd_real[:, -1:]
else:
    scale_real = None
mu, logvar = generator.encode(ghd_real, scale_real)
z_l = mu[shape_id_l].unsqueeze(0)
z_r = mu[shape_id_r].unsqueeze(0)
# z_l = -1 * torch.ones(1, latent_dim).to(device)
# z_r = 0 * torch.ones(1, latent_dim).to(device)
z = []
for i in range(B):
    alpha = i / (B - 1)
    z.append((1 - alpha) * z_l + alpha * z_r)
z = torch.cat(z, 0)
if withscale:
    ghd_fake, scale_fake = generator.decode(z, False)
    scale_fake = dataset.denorm_scale(scale_fake)
else:
    ghd_fake = generator.decode(z, True)
    scale_fake = None
data_fake = ghd_reconstruct.forward(ghd_fake, mean, std, use_norm)
fig = get_fig(ghd_reconstruct, data_fake, 5, Title="Interpolation", scale=scale_fake)
save_path = "render/images/unconditional/{}/{}.png".format(label, meta)
os.makedirs(os.path.dirname(save_path), exist_ok=True)
plt.savefig(save_path)
plt.show(fig)

meshes = ghd_reconstruct.ghd_forward_as_Meshes(ghd_fake * std.to(device) + mean.to(device), denormalize_shape=False, trimmed_faces=mesh_plugin.trimmed_faces)
if get_gif:
    mesh_render.render_rotational_gif(meshes, dual_texture=False, n_row=5, fps=36, out_dir=None, label=label)
try:
    display(Image(filename=f"./render/gifs/{label}.gif"))
except:
    pass
if save_objs:
    save_dir = "render/meshes/unconditional/{}/{}".format(label, meta)
    os.makedirs(os.path.dirname(save_dir), exist_ok=True)
    mesh_render.save_objs(meshes, label, save_dir=save_dir)

# %%
from pytorch3d.structures import Meshes
ghd_real = next(iter(dataloader)).to(device)
if withscale:
    ghd_real, scale_real = ghd_real[:, :-1], ghd_real[:, -1:]
else:
    scale_real = None
    
B = 10 * ghd_real.shape[0]
z = torch.randn(B, latent_dim).to(device)
if withscale:
    ghd_fake, scale_fake = generator.decode(z, False)
else:
    ghd_fake = generator.decode(z, True)
    scale_fake = None
data_real = ghd_reconstruct.forward(ghd_real, mean, std, use_norm)
data_fake = ghd_reconstruct.forward(ghd_fake, mean, std, use_norm)
data_real = data_real.to_data_list()
data_fake = data_fake.to_data_list()
reg_real = []
reg_fake = []
canonical_mesh = ghd_reconstruct.canonical_Meshes.to(device)
for data_real_ in data_real:
    reg_real.append(rigidloss(data_real_.pos))
for data_fake_ in data_fake:
    reg_fake.append(rigidloss(data_fake_.pos))

reg_real = torch.stack(reg_real).detach().cpu().numpy()
reg_fake = torch.stack(reg_fake).detach().cpu().numpy()
print(reg_real.shape, reg_fake.shape)
plt.figure(figsize=(10, 6))
data = [reg_real, reg_fake]
# for i, d in enumerate(data):
#     x = np.random.normal(loc=i + 1, scale=0.04, size=len(d))  # Add jitter to x-coordinates
#     plt.scatter(x, d, alpha=0.7, color='darkblue', edgecolor='white', s=20)
plt.violinplot(data, showmeans=True, showextrema=True)
plt.xticks([1, 2], ['Real', 'Fake'])
plt.ylabel('Rigid Loss')
plt.title('Distribution of Rigid Loss for Real and Fake Data')
save_path = "render/images/unconditional/{}/{}.png".format("rigid_distribution", meta)
os.makedirs(os.path.dirname(save_path), exist_ok=True)
plt.savefig(save_path)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Parameters for the non-standard Gaussian distribution
mu = 0  # Mean
sigma = 2  # Standard deviation (makes the distribution wider and lower in height)
amplitude = 0.1  # Reduces the height of the distribution

# Generate data for the non-standard Gaussian distribution
x = np.linspace(-6, 6, 1000)
y = amplitude * (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)

# Create a much lighter red-like gradient colormap for the fill
cmap = LinearSegmentedColormap.from_list('light_red_gradient', ['lavenderblush', 'lightcoral'])

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the Gaussian curve with a black line
ax.plot(x, y, color='black', linewidth=2)

# Fill under the curve with the gradient color along the y-axis
for i in range(len(x) - 1):
    ax.fill_between(x[i:i+2], y[i:i+2], color=cmap(y[i] / y.max()), alpha=1)

# Remove axes
ax.axis('off')

# Show the plot
plt.savefig("render/images/unconditional/{}.png".format("gaussian2"))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Parameters for the non-standard Gaussian distribution
mu = 0  # Mean
sigma = 2  # Standard deviation (makes the distribution wider and lower in height)
amplitude = 0.1  # Reduces the height of the distribution

# Generate data for the non-standard Gaussian distribution
x = np.linspace(-8, 8, 1000)
y = amplitude * (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)

# Create a much lighter red-like gradient colormap for the fill
cmap = LinearSegmentedColormap.from_list('blue_gradient', ['aliceblue', 'skyblue'])

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the Gaussian curve with a black line
ax.plot(x, y, color='black', linewidth=2)

# Fill under the curve with the gradient color along the y-axis
for i in range(len(x) - 1):
    ax.fill_between(x[i:i+2], y[i:i+2], color=cmap(y[i] / y.max()), alpha=1)

# Remove axes
ax.axis('off')

# Show the plot
plt.savefig("render/images/unconditional/{}.png".format("gaussian1"))
plt.show()

# %%
import os
import shutil

original_root = '/media/yaplab/"HDD Storage"/wenhao/ghb_aneurysms/checkpoints/fit_mca_stable'
new_root = '/media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/ghd_fitting'
folders = [dir for dir in os.listdir(original_root) if os.path.isdir(os.path.join(original_root, dir))]
file_list = ["ghb_fitting_checkpoint_5.pkl"]
for folder in folders:
    original_subfolder = os.path.join(original_root, folder, "vanilla")
    new_subfolder = os.path.join(new_root, folder, "vanilla")
    if not os.path.exists(original_subfolder):
        continue
    for file_ in file_list:
        if file_ in os.listdir(original_subfolder):
            os.makedirs(new_subfolder, exist_ok=True)
            shutil.copy2(os.path.join(original_subfolder, file_), os.path.join(new_subfolder, file_))
            print("{} has been copied".format(os.path.join(new_root, folder, file_)))

# %%
import os
import shutil

original_root = '/media/yaplab/"HDD Storage"/wenhao/ghb_aneurysms/checkpoints/align_mca_stable'
new_root = '/media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment'
folders = [dir for dir in os.listdir(original_root) if os.path.isdir(os.path.join(original_root, dir))]
file_list = ["aligned_centreline.pkl", "alignment_checkpoint.pkl", "part_aligned_updated.obj", "diff_centreline_checkpoint.pkl",
             "opa_checkpoint.pkl", "part_aligned.obj", "part_aligned_updated.obj"]
for folder in folders:
    original_subfolder = os.path.join(original_root, folder)
    new_subfolder = os.path.join(new_root, folder)
    if not os.path.exists(original_subfolder):
        continue
    for file_ in file_list:
        if file_ in os.listdir(original_subfolder):
            os.makedirs(new_subfolder, exist_ok=True)
            shutil.copy2(os.path.join(original_subfolder, file_), os.path.join(new_subfolder, file_))
            print("{} has been copied".format(os.path.join(new_root, folder, file_)))
# Out:
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0284.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0284.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0284.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0284.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0284.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0284.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0284.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p163_EwkdAxESDAkcBwcVEQkBBxQC/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p163_EwkdAxESDAkcBwcVEQkBBxQC/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p163_EwkdAxESDAkcBwcVEQkBBxQC/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p163_EwkdAxESDAkcBwcVEQkBBxQC/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p163_EwkdAxESDAkcBwcVEQkBBxQC/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p163_EwkdAxESDAkcBwcVEQkBBxQC/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p163_EwkdAxESDAkcBwcVEQkBBxQC/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p397_GBQVAAMWBwYSFg4aFQAdDQAf/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p397_GBQVAAMWBwYSFg4aFQAdDQAf/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p397_GBQVAAMWBwYSFg4aFQAdDQAf/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p397_GBQVAAMWBwYSFg4aFQAdDQAf/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p397_GBQVAAMWBwYSFg4aFQAdDQAf/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p397_GBQVAAMWBwYSFg4aFQAdDQAf/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p397_GBQVAAMWBwYSFg4aFQAdDQAf/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p333_AhQdDQMWBw4fFhQaHQ0dFwAX/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p333_AhQdDQMWBw4fFhQaHQ0dFwAX/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p333_AhQdDQMWBw4fFhQaHQ0dFwAX/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p333_AhQdDQMWBw4fFhQaHQ0dFwAX/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p333_AhQdDQMWBw4fFhQaHQ0dFwAX/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p333_AhQdDQMWBw4fFhQaHQ0dFwAX/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p333_AhQdDQMWBw4fFhQaHQ0dFwAX/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0103.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0103.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0103.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0103.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0103.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0103.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0103.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p095_EhMHDx4NAB8BEAgBFxMMFwAW_LICA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p095_EhMHDx4NAB8BEAgBFxMMFwAW_LICA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p095_EhMHDx4NAB8BEAgBFxMMFwAW_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p095_EhMHDx4NAB8BEAgBFxMMFwAW_LICA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p095_EhMHDx4NAB8BEAgBFxMMFwAW_LICA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p095_EhMHDx4NAB8BEAgBFxMMFwAW_LICA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p095_EhMHDx4NAB8BEAgBFxMMFwAW_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0070/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0070/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0070/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0070/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0070/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0070/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0070/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0041/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0041/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0041/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0041/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0041/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0041/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0041/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p158_Fg4bEgMJER8cDBUcEwIIChwL/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p158_Fg4bEgMJER8cDBUcEwIIChwL/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p158_Fg4bEgMJER8cDBUcEwIIChwL/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p158_Fg4bEgMJER8cDBUcEwIIChwL/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p158_Fg4bEgMJER8cDBUcEwIIChwL/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p158_Fg4bEgMJER8cDBUcEwIIChwL/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p158_Fg4bEgMJER8cDBUcEwIIChwL/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p362_HgABERkGAQoaGwccAggAFh4R_LMCA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p362_HgABERkGAQoaGwccAggAFh4R_LMCA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p362_HgABERkGAQoaGwccAggAFh4R_LMCA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p362_HgABERkGAQoaGwccAggAFh4R_LMCA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p362_HgABERkGAQoaGwccAggAFh4R_LMCA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p362_HgABERkGAQoaGwccAggAFh4R_LMCA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p362_HgABERkGAQoaGwccAggAFh4R_LMCA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p338_FwQdExcNAR8WChQIFxIJABoK_RICA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p338_FwQdExcNAR8WChQIFxIJABoK_RICA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p338_FwQdExcNAR8WChQIFxIJABoK_RICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p338_FwQdExcNAR8WChQIFxIJABoK_RICA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p338_FwQdExcNAR8WChQIFxIJABoK_RICA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p338_FwQdExcNAR8WChQIFxIJABoK_RICA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p338_FwQdExcNAR8WChQIFxIJABoK_RICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0030/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0030/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0030/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0030/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0030/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0030/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0030/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000482/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000482/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000482/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000482/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000482/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000482/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000482/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p403_BAkXCB4cCB8bAA8BBhsaDRAR/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p403_BAkXCB4cCB8bAA8BBhsaDRAR/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p403_BAkXCB4cCB8bAA8BBhsaDRAR/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p403_BAkXCB4cCB8bAA8BBhsaDRAR/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p403_BAkXCB4cCB8bAA8BBhsaDRAR/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p403_BAkXCB4cCB8bAA8BBhsaDRAR/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p403_BAkXCB4cCB8bAA8BBhsaDRAR/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0106.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0106.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0106.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0106.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0106.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0106.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0106.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_03/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_03/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_03/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_03/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_03/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_03/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_03/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0222.00_ID3/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0222.00_ID3/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0222.00_ID3/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0222.00_ID3/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0222.00_ID3/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0222.00_ID3/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0222.00_ID3/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_01/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_01/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_01/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_01/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_01/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_01/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000592_01/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0038.00_ID2/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0038.00_ID2/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0038.00_ID2/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0038.00_ID2/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0038.00_ID2/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0038.00_ID2/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0038.00_ID2/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p496_HQgeCRkcDAgfDQ8bHwgCDRwM/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p496_HQgeCRkcDAgfDQ8bHwgCDRwM/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p496_HQgeCRkcDAgfDQ8bHwgCDRwM/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p496_HQgeCRkcDAgfDQ8bHwgCDRwM/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p496_HQgeCRkcDAgfDQ8bHwgCDRwM/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p496_HQgeCRkcDAgfDQ8bHwgCDRwM/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p496_HQgeCRkcDAgfDQ8bHwgCDRwM/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0098/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0098/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0098/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0098/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0098/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0098/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0098/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p501_GAQWCBcNAB8WAQ8IFxMGABER/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p501_GAQWCBcNAB8WAQ8IFxMGABER/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p501_GAQWCBcNAB8WAQ8IFxMGABER/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p501_GAQWCBcNAB8WAQ8IFxMGABER/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p501_GAQWCBcNAB8WAQ8IFxMGABER/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p501_GAQWCBcNAB8WAQ8IFxMGABER/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p501_GAQWCBcNAB8WAQ8IFxMGABER/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p442_EhMHDx4NAB8BEAgBFxMMFwAW_RICA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p442_EhMHDx4NAB8BEAgBFxMMFwAW_RICA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p442_EhMHDx4NAB8BEAgBFxMMFwAW_RICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p442_EhMHDx4NAB8BEAgBFxMMFwAW_RICA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p442_EhMHDx4NAB8BEAgBFxMMFwAW_RICA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p442_EhMHDx4NAB8BEAgBFxMMFwAW_RICA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p442_EhMHDx4NAB8BEAgBFxMMFwAW_RICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0020/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0020/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0020/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0020/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0020/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0020/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0020/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0050/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0050/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0050/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0050/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0050/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0050/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0050/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000411/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000411/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000411/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000411/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000411/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000411/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000411/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0224.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0224.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0224.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0224.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0224.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0224.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0224.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000175/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000175/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000175/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000175/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000175/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000175/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000175/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p126_FAQBCQUbAQQAGwMcGhQdFhAL/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p126_FAQBCQUbAQQAGwMcGhQdFhAL/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p126_FAQBCQUbAQQAGwMcGhQdFhAL/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p126_FAQBCQUbAQQAGwMcGhQdFhAL/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p126_FAQBCQUbAQQAGwMcGhQdFhAL/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p126_FAQBCQUbAQQAGwMcGhQdFhAL/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p126_FAQBCQUbAQQAGwMcGhQdFhAL/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p383_HQ4ABB4HDA4BAAgAHw4cABsX/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p383_HQ4ABB4HDA4BAAgAHw4cABsX/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p383_HQ4ABB4HDA4BAAgAHw4cABsX/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p383_HQ4ABB4HDA4BAAgAHw4cABsX/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p383_HQ4ABB4HDA4BAAgAHw4cABsX/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0092.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0092.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0092.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0092.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0092.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0092.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0092.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0099.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0099.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0099.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0099.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0099.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0099.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0099.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p485_FwkXAwINHAQUEBURGgQMFxAW/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p485_FwkXAwINHAQUEBURGgQMFxAW/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p485_FwkXAwINHAQUEBURGgQMFxAW/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p485_FwkXAwINHAQUEBURGgQMFxAW/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p485_FwkXAwINHAQUEBURGgQMFxAW/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p485_FwkXAwINHAQUEBURGgQMFxAW/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p485_FwkXAwINHAQUEBURGgQMFxAW/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p411_HBQcAAIMGx8GCwcdFggCEBsZ_LICA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p411_HBQcAAIMGx8GCwcdFggCEBsZ_LICA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p411_HBQcAAIMGx8GCwcdFggCEBsZ_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p411_HBQcAAIMGx8GCwcdFggCEBsZ_LICA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p411_HBQcAAIMGx8GCwcdFggCEBsZ_LICA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p411_HBQcAAIMGx8GCwcdFggCEBsZ_LICA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p411_HBQcAAIMGx8GCwcdFggCEBsZ_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0089.00_ID2/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0089.00_ID2/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0089.00_ID2/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0089.00_ID2/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0089.00_ID2/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0089.00_ID2/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0089.00_ID2/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p122_BAQWBAMLHR8WAQMcEQ4aABEd/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p122_BAQWBAMLHR8WAQMcEQ4aABEd/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p122_BAQWBAMLHR8WAQMcEQ4aABEd/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p122_BAQWBAMLHR8WAQMcEQ4aABEd/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p122_BAQWBAMLHR8WAQMcEQ4aABEd/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p122_BAQWBAMLHR8WAQMcEQ4aABEd/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p122_BAQWBAMLHR8WAQMcEQ4aABEd/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000553_02/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000553_02/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000553_02/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000553_02/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000553_02/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000553_02/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000553_02/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000425/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000425/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000425/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000425/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000425/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000425/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000425/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p486_AwQAFxEBAR8WFxAOGxIdAAcO/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p486_AwQAFxEBAR8WFxAOGxIdAAcO/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p486_AwQAFxEBAR8WFxAOGxIdAAcO/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p486_AwQAFxEBAR8WFxAOGxIdAAcO/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p486_AwQAFxEBAR8WFxAOGxIdAAcO/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p486_AwQAFxEBAR8WFxAOGxIdAAcO/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p486_AwQAFxEBAR8WFxAOGxIdAAcO/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0029/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0029/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0029/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0029/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0029/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0029/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0029/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p462_EwAADxURDAABCwMWEQAcCxAB/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p462_EwAADxURDAABCwMWEQAcCxAB/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p462_EwAADxURDAABCwMWEQAcCxAB/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p462_EwAADxURDAABCwMWEQAcCxAB/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p462_EwAADxURDAABCwMWEQAcCxAB/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p462_EwAADxURDAABCwMWEQAcCxAB/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p462_EwAADxURDAABCwMWEQAcCxAB/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p424_FBQUDgUaDBQVChMdFhQICgAK/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p424_FBQUDgUaDBQVChMdFhQICgAK/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p424_FBQUDgUaDBQVChMdFhQICgAK/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p424_FBQUDgUaDBQVChMdFhQICgAK/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p424_FBQUDgUaDBQVChMdFhQICgAK/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p424_FBQUDgUaDBQVChMdFhQICgAK/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p424_FBQUDgUaDBQVChMdFhQICgAK/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0014/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0014/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0014/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0014/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0014/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0014/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0014/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p154_HRQeDRUaDBQfCQMdHxQCCRAK/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p154_HRQeDRUaDBQfCQMdHxQCCRAK/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p154_HRQeDRUaDBQfCQMdHxQCCRAK/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p154_HRQeDRUaDBQfCQMdHxQCCRAK/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p154_HRQeDRUaDBQfCQMdHxQCCRAK/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p154_HRQeDRUaDBQfCQMdHxQCCRAK/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p154_HRQeDRUaDBQfCQMdHxQCCRAK/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0069/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0069/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0069/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0069/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0069/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0069/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0069/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_02/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_02/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_02/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_02/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_02/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_02/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_02/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p377_AA0TDwQBBAQSEBgDEw8aDAMd_LMCA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p377_AA0TDwQBBAQSEBgDEw8aDAMd_LMCA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p377_AA0TDwQBBAQSEBgDEw8aDAMd_LMCA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p377_AA0TDwQBBAQSEBgDEw8aDAMd_LMCA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p377_AA0TDwQBBAQSEBgDEw8aDAMd_LMCA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p377_AA0TDwQBBAQSEBgDEw8aDAMd_LMCA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p377_AA0TDwQBBAQSEBgDEw8aDAMd_LMCA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0176.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0176.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0176.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0176.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0176.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0176.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0176.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p444_GBQVFBUGHRUHABgaFRQLCxoM/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p444_GBQVFBUGHRUHABgaFRQLCxoM/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p444_GBQVFBUGHRUHABgaFRQLCxoM/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p444_GBQVFBUGHRUHABgaFRQLCxoM/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p444_GBQVFBUGHRUHABgaFRQLCxoM/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p444_GBQVFBUGHRUHABgaFRQLCxoM/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p444_GBQVFBUGHRUHABgaFRQLCxoM/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0120.00_ID2/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0120.00_ID2/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0120.00_ID2/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0120.00_ID2/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0120.00_ID2/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0120.00_ID2/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0120.00_ID2/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p404_EgAAAxUSExUNBBQNFxsPERcZ/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p404_EgAAAxUSExUNBBQNFxsPERcZ/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p404_EgAAAxUSExUNBBQNFxsPERcZ/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p404_EgAAAxUSExUNBBQNFxsPERcZ/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p404_EgAAAxUSExUNBBQNFxsPERcZ/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_01/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_01/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_01/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_01/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_01/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_01/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000497_01/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p413_GgAREAUBFxMNBAUeBwgLFx8Z_RICA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p413_GgAREAUBFxMNBAUeBwgLFx8Z_RICA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p413_GgAREAUBFxMNBAUeBwgLFx8Z_RICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p413_GgAREAUBFxMNBAUeBwgLFx8Z_RICA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p413_GgAREAUBFxMNBAUeBwgLFx8Z_RICA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p413_GgAREAUBFxMNBAUeBwgLFx8Z_RICA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p413_GgAREAUBFxMNBAUeBwgLFx8Z_RICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0211.00_ID1/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0211.00_ID1/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0211.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0211.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0211.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0211.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0211.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000270/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000270/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000270/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000270/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000270/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000270/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000270/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000185/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000185/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000185/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000185/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000185/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000185/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000185/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0108.00_ID1/aligned_centreline.pkl has been copied
# ...
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0290.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0290.00_ID1/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0290.00_ID1/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0290.00_ID1/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/UPF_P0290.00_ID1/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p170_EgQABhUaDAQBAgMdEAQcAhAK/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p170_EgQABhUaDAQBAgMdEAQcAhAK/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p170_EgQABhUaDAQBAgMdEAQcAhAK/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p170_EgQABhUaDAQBAgMdEAQcAhAK/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p170_EgQABhUaDAQBAgMdEAQcAhAK/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p170_EgQABhUaDAQBAgMdEAQcAhAK/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p170_EgQABhUaDAQBAgMdEAQcAhAK/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000316/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000316/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000316/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000316/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000316/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000316/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/SNF00000316/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/ANSYS_UNIGE_09/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/ANSYS_UNIGE_09/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/ANSYS_UNIGE_09/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/ANSYS_UNIGE_09/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/ANSYS_UNIGE_09/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/ANSYS_UNIGE_09/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/ANSYS_UNIGE_09/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0057b/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0057b/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0057b/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0057b/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0057b/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0057b/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0057b/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p388_Ag4BEhUcDA4AFgMbAA4dFhAM/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p388_Ag4BEhUcDA4AFgMbAA4dFhAM/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p388_Ag4BEhUcDA4AFgMbAA4dFhAM/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p388_Ag4BEhUcDA4AFgMbAA4dFhAM/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p388_Ag4BEhUcDA4AFgMbAA4dFhAM/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p388_Ag4BEhUcDA4AFgMbAA4dFhAM/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p388_Ag4BEhUcDA4AFgMbAA4dFhAM/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0031/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0031/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0031/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0031/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0031/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0031/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0031/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0023/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0023/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0023/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0023/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0023/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0023/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0023/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0012/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0012/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0012/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0012/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0012/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0012/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0012/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p490_EhMHDx4NAB8BEAgBFxMMFwAW/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p490_EhMHDx4NAB8BEAgBFxMMFwAW/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p490_EhMHDx4NAB8BEAgBFxMMFwAW/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p490_EhMHDx4NAB8BEAgBFxMMFwAW/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p490_EhMHDx4NAB8BEAgBFxMMFwAW/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p490_EhMHDx4NAB8BEAgBFxMMFwAW/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p490_EhMHDx4NAB8BEAgBFxMMFwAW/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/canonical_typeB/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/canonical_typeB/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/canonical_typeB/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/canonical_typeB/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/canonical_typeB/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/canonical_typeB/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/canonical_typeB/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0056/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0056/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0056/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0056/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0056/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0056/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0056/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p304_HQQLDREGDAQKCQcBHwQXCRQW_LICA/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p304_HQQLDREGDAQKCQcBHwQXCRQW_LICA/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p304_HQQLDREGDAQKCQcBHwQXCRQW_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p304_HQQLDREGDAQKCQcBHwQXCRQW_LICA/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p304_HQQLDREGDAQKCQcBHwQXCRQW_LICA/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0013/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0013/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0013/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0013/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0013/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0013/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_0013/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0092/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0092/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0092/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0092/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0092/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0092/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0092/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p429_HBQIGxkWBxsJDAoaCBsHCQAC/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p429_HBQIGxkWBxsJDAoaCBsHCQAC/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p429_HBQIGxkWBxsJDAoaCBsHCQAC/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p429_HBQIGxkWBxsJDAoaCBsHCQAC/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p429_HBQIGxkWBxsJDAoaCBsHCQAC/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p429_HBQIGxkWBxsJDAoaCBsHCQAC/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/p429_HBQIGxkWBxsJDAoaCBsHCQAC/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0071/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0071/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0071/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0071/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0071/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0071/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0071/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_UNIGE_0029/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_UNIGE_0029/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_UNIGE_0029/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_UNIGE_0029/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/USFD_UNIGE_0029/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0077/aligned_centreline.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0077/alignment_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0077/part_aligned_updated.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0077/diff_centreline_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0077/opa_checkpoint.pkl has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0077/part_aligned.obj has been copied
# /media/yaplab/"HDD Storage"/wenhao/AneuG/checkpoints/alignment/C0077/part_aligned_updated.obj has been copied
